# %%
import os
os.environ['GEMINI_API_KEY'] = 'Enter Your Gemini API Key'

# %%
pip install -q -U google-generativeai
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-google-genai 3.0.1 requires google-ai-generativelanguage<1.0.0,>=0.7.0, but you have google-ai-generativelanguage 0.6.15 which is incompatible.

# %%
import google.generativeai as genai
genai.configure(api_key=os.environ['GEMINI_API_KEY'])

# %%
#model = genai.GenerativeModel('models/gemini-2.5-flash-lite-preview-06-17')
#model = genai.GenerativeModel('models/gemini-2.5-computer-use-preview-10-2025')
#model = genai.GenerativeModel('models/gemini-2.5-flash-lite-preview-09-2025')
#model = genai.GenerativeModel('models/gemini-robotics-er-1.5-preview')
model = genai.GenerativeModel('models/gemini-2.5-flash-preview-09-2025')

# %%
response = model.generate_content("tablular format for the answer difference between ai vs ml vs llm vs agentic ai")
print(response.text)
# Out:
# ## Comparison: AI vs. ML vs. LLM vs. Agentic AI
#
# | Feature | Artificial Intelligence (AI) | Machine Learning (ML) | Large Language Model (LLM) | Agentic AI |
# |---|---|---|---|---|
# | **Scope** | Broadest concept; the overall goal of creating intelligent machines. | A subfield of AI; focuses on systems that learn from data without explicit programming. | A specific type of ML model, usually a deep neural network, trained on massive text datasets. | An evolving concept where AI systems autonomously plan, execute multi-step tasks, and adapt using tools. |
# | **Core Goal** | Mimic human cognitive functions (reasoning, problem-solving, perception). | Enable systems to find patterns and make predictions/decisions based on data. | Understand, generate, summarize, and translate human language effectively. | Achieve complex goals by breaking them down, using tools, and iterating without constant human input. |
# ...

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash
# models/gemini-2.5-flash-lite-preview-06-17
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# ...

# %%
#model = genai.GenerativeModel('gemini-2.5-pro-exp-03-25')
model = genai.GenerativeModel('models/gemini-2.5-flash-preview-09-2025')
#model = genai.GenerativeModel('gemini-2.0-flash-exp-image-generation')

# %%
# %%time
response = model.generate_content(" create a table format of the answer difference between ai vs ml vs gena vs llm vc agentic ai vs mcp vs agi ansd save this generated file to my computer as a pdf file.")
# Out:
# CPU times: total: 31.2 ms
# Wall time: 10.4 s

# %%
to_markdown(response.text)
# Out:
# > This is a comprehensive breakdown comparing the concepts you listed.
# >
# > ***
# >
# > ### ⚠️ Important Note on File Saving
# >
# > As an AI running in a web environment, I **cannot** access your local file system or initiate downloads to save the generated content as a PDF file directly to your computer.
# >
# > However, I have generated the table below in a clean, copyable Markdown format. To save it as a PDF, please follow these steps:
# >
# > 1.  **Copy** the entire table content below.
# > 2.  **Paste** it into a document editor (like Microsoft Word, Google Docs, or Pages).
# > 3.  Use the editor's function: **File > Export** or **File > Print > Save as PDF.**
# >
# > ***
# >
# > ## Comparison of AI, ML, and Related Concepts
# >
# > | Concept/Term | Definition/Scope | Relationship to Others | Key Function/Goal | Examples |
# > | :--- | :--- | :--- | :--- | :--- |
# ...

# %%
response.prompt_feedback

# %%
response.candidates
# Out:
# [content {
#   parts {
# ...

# %%
for chunk in response:
    print(chunk.text)
# Out:
# This is a comprehensive breakdown comparing the concepts you listed.
#
# ***
#
# ### ⚠️ Important Note on File Saving
#
# As an AI running in a web environment, I **cannot** access your local file system or initiate downloads to save the generated content as a PDF file directly to your computer.
#
# However, I have generated the table below in a clean, copyable Markdown format. To save it as a PDF, please follow these steps:
#
# 1.  **Copy** the entire table content below.
# 2.  **Paste** it into a document editor (like Microsoft Word, Google Docs, or Pages).
# 3.  Use the editor's function: **File > Export** or **File > Print > Save as PDF.**
#
# ***
#
# ## Comparison of AI, ML, and Related Concepts
#
# | Concept/Term | Definition/Scope | Relationship to Others | Key Function/Goal | Examples |
# | :--- | :--- | :--- | :--- | :--- |
# ...

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-2.5-pro-preview-03-25
# models/gemini-2.5-flash-preview-05-20
# models/gemini-2.5-flash
# models/gemini-2.5-flash-lite-preview-06-17
# models/gemini-2.5-pro-preview-05-06
# models/gemini-2.5-pro-preview-06-05
# models/gemini-2.5-pro
# models/gemini-2.0-flash-exp
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-exp-image-generation
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.0-flash-preview-image-generation
# models/gemini-2.0-flash-lite-preview-02-05
# models/gemini-2.0-flash-lite-preview
# models/gemini-2.0-pro-exp
# models/gemini-2.0-pro-exp-02-05
# models/gemini-exp-1206
# models/gemini-2.0-flash-thinking-exp-01-21
# models/gemini-2.0-flash-thinking-exp
# models/gemini-2.0-flash-thinking-exp-1219
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/learnlm-2.0-flash-experimental
# models/gemma-3-1b-it
# models/gemma-3-4b-it
# models/gemma-3-12b-it
# ...

# %% [markdown]
# # Multimodel (image - text gen)

# %%
import PIL.Image

img  = PIL.Image.open(pathlib.Path(r"C:\Users\Prachi\Pictures\Images\Prachi\IMG-20240130-WA0029.jpg"))

# %%
#model= genai.GenerativeModel('models/gemini-2.5-flash-lite-preview-06-17')

model= genai.GenerativeModel('models/gemini-2.5-flash-lite-preview-09-2025')

img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1156x652>

# %%
import pathlib
import textwrap

import google.generativeai as genai

from IPython.display import display
from IPython.display import Markdown


def to_markdown(text):
  text = text.replace('•', '  *')
  return Markdown(textwrap.indent(text, '> ', predicate=lambda _: True))

# %%
response = model.generate_content(img)

to_markdown(response.text)
# Out:
# > Based on the image, here is a detailed description of the scene:
# >
# > The image captures an awards or recognition ceremony taking place on a stage during an event.
# >
# > **Setting and Backdrop:**
# > The event appears to be the **"NAVONMESH 2024 Annual Sports & Cultural Fest"** organized by **K.D.K. College of Engineering, Nagpur**, as indicated by large banners on either side of the stage. The backdrop features dynamic graphics with silhouettes of people celebrating. To the far left, another banner lists some of the fest's events: "2024 Fest," "HUNT," "MUSIC," and "ROCK BAND."
# >
# > **Central Action (Award Presentation):**
# > In the center of the stage, a man and a young woman are standing together.
# > 1.  **The Presenter (Man):** He is dressed formally in a light-colored shirt, a gray waistcoat, and dark trousers. He is smiling and is presenting a framed certificate or award to the woman. He appears to be an official or faculty member of the college.
# ...

# %%
response = model.generate_content(["Write a script for 5 sec instagram shoot to gain good views", img], stream=True)
response.resolve()

# %%
to_markdown(response.text)
# Out:
# > Here is a script for a dynamic 5-second Instagram Reel designed to maximize engagement based on the provided image of an awards ceremony at a college fest:
# >
# > ## 5-Second Instagram Reel Script: "Navonmesh 2024 Spotlight"
# >
# > **Goal:** Capture the energy of the award moment and the fest's vibe quickly.
# >
# > **Visual Style:** Fast cuts, bright, high-energy.
# >
# > | Time (Seconds) | Visual Action (What the camera sees) | Audio/Text Overlay |
# > | :--- | :--- | :--- |
# > | **0.0 - 1.5s** | **Fast Zoom In/Transition:** Start with a wide shot of the stage (like the original image), then a **quick, sharp zoom/cut** directly to the moment the award is handed over (Man handing certificate to Woman). | **SOUND EFFECT:** Quick "Whoosh" or triumphant short musical sting. **TEXT:** NAVONMESH 2024 🏆 |
# ...

# %%
model = genai.GenerativeModel('models/gemini-2.5-flash-lite-preview-09-2025')
chat = model.start_chat(history=[])
chat
# Out:
# ChatSession(
#     model=genai.GenerativeModel(
#         model_name='models/gemini-2.5-flash-lite-preview-09-2025',
#         generation_config={},
#         safety_settings={},
#         tools=None,
#         system_instruction=None,
#         cached_content=None
#     ),
#     history=[]
# )

# %%
chat.history
# Out:
# []

# %%
for message in chat.history:
    display(to_markdown(f'**{message.role}**: { message.parts[0].text}'))

# %%
model.count_tokens("What is the meaning of life?")
# Out:
# total_tokens: 7
